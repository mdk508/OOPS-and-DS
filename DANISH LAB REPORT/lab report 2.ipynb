# %% [markdown]
# <center>
#     <div style="
#         background: linear-gradient(90deg, #c83349, #622569);
#         padding: 30px 20px;
#         border-radius: 25px;
#         box-shadow: 0 7px 6px rgba(0, 0, 0, 0.3);
#         display: inline-block;
#         border: 2px solid #CCCCFF;
#         max-width: 90%;
#     ">
#         <span style="
#             font-size: 30px;
#             font-family: Cooper Black;
#             color: #FFBF00;
#             font-weight: bold;
#             letter-spacing: 1px;
#             text-shadow: 3px 1px 8px rgba(0, 0, 1, 0.6);
#         ">
#             Lab REPORT LAB NO 2
#         </span>
#     </div>
# </center>

# %% [markdown]
# ![lab report 2.PNG](attachment:0f57356b-3b46-4a10-b12f-67560deae755.PNG)

# %% [markdown]
# <span style="color: #000000;
# font-size: 44px;
# transition: color 0.3s;">&#x21DD; </span>
# <span style="color: #FFA500;
#     font-family: Arial Black;
# font-size: 35px; font-weight: bold;
# text-shadow: 0px 4px 2px rgb(0, 0, 0);">
#    a. Function with positional arguments: :</span>

# %%
def calculate_voltage_positional(current, resistance):
    voltage = current * resistance
    return voltage

# %% [markdown]
# <span style="color: #000000;
# font-size: 44px;
# transition: color 0.3s;">&#x21DD; </span>
# <span style="color: #FFA500;
#     font-family: Arial Black;
# font-size: 35px; font-weight: bold;
# text-shadow: 0px 4px 2px rgb(0, 0, 0);">
#  b. Function with keyword arguments:: :</span>

# %%
def calculate_voltage_keyword(current, resistance):
    voltage = current * resistance
    return voltage

# %%
calculate_voltage_keyword(current=5, resistance=10)
# Out:
# 50

# %% [markdown]
# <span style="color: #000000;
# font-size: 44px;
# transition: color 0.3s;">&#x21DD; </span>
# <span style="color: #FFA500;
#     font-family: Arial Black;
# font-size: 35px; font-weight: bold;
# text-shadow: 0px 4px 2px rgb(0, 0, 0);">
# c. Function with default arguments: :</span>

# %%
def calculate_voltage_default(current=1, resistance=1):
    voltage = current * resistance
    return voltage

# %% [markdown]
# <center><span style="color:black;
# font-family:Algerian;
# font-weight:bold;
# font-size:35px;">Passing positional arguments to a keyword argument function: </span></center>

# %%
calculate_voltage_keyword(9, 10)
# Out:
# 90

# %% [markdown]
# <center><span style="color:black;
# font-family:Algerian;
# font-weight:bold;
# font-size:35px;">Passing keyword arguments to a positional argument function </span></center>

# %%
calculate_voltage_positional(current=10, resistance=10)
# Out:
# 100

# %% [markdown]
# <center><span style="color:black;
# font-family:Algerian;
# font-weight:bold;
# font-size:35px;">e. Passing fewer arguments and checking the error: </span></center>

# %%
calculate_voltage_positional(5,4)  # Missing the 'resistance' argument,4
# Out:
# 20

# %%
voltage_error = calculate_voltage_positional(5, 10)

# %% [markdown]
# <center><span style="color:black;
# font-family:Algerian;
# font-weight:bold;
# font-size:35px;">f. Verify that positional arguments follow keyword arguments: </span></center>

# %%
calculate_voltage_positional(5, resistance=10)  # Valid
# Out:
# 50
